# %% [markdown]
# ## imports

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.linear_model import LogisticRegression

# %%
music = pd.read_csv("MusicDataset.csv")
music.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %% [markdown]
# ## dataset exploration

# %%
music.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
music['artists']
# Out:
# 0                    Gen Hoshino
# 1                   Ben Woodward
# 2         Ingrid Michaelson;ZAYN
# 3                   Kina Grannis
# 4               Chord Overstreet
#                    ...
# 113995             Rainy Lullaby
# 113996             Rainy Lullaby
# 113997             Cesária Evora
# 113998          Michael W. Smith
# 113999             Cesária Evora
# Name: artists, Length: 114000, dtype: object

# %%
music.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
music['mood'] = music.loc[music['valence'] > 0.5, 'mood'] = 1
music['mood'] = music.loc[music['valence'] <= 0.5, 'mood'] = 0
music
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
musicX = music.loc[:, music.columns == 'mode']
musicX.shape
# Out:
# (114000, 1)

# %%
musicx = music.drop(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name', 'mode', 'duration_ms', 'valence', 'time_signature', 'track_genre', 'mood', 'explicit'], axis = 1)
musicx.shape
# Out:
# (114000, 10)

# %%
musicY = music.loc[:, music.columns == 'mood']
musicY.shape
# Out:
# (114000, 1)

# %%
musicy = music.loc[:, music.columns == 'valence']
musicy.shape
# Out:
# (114000, 1)

# %%
x_train, y_train, x_test, y_test = train_test_split(musicX, musicY, test_size = 0.5, random_state = 99 )

# %%
musicclf = RandomForestClassifier(criterion = 'entropy', max_depth = 15, min_samples_split = 10, random_state = 5)

# %%
musicclf.fit(x_train, y_train)
# Out:
# C:\Users\madzi\AppData\Local\Temp\ipykernel_2736\1038367713.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   musicclf.fit(x_train, y_train)
# RandomForestClassifier(criterion='entropy', max_depth=15, min_samples_split=10,
#                        random_state=5)

# %%
y_pred = musicclf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 y_pred = musicclf.predict(x_test)
#
# File ~\.anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:820, in ForestClassifier.predict(self, X)
#     799 def predict(self, X):
#     800     """
#     801     Predict class for X.
#     802
#    (...)
#     818         The predicted classes.
#     819     """
# --> 820     proba = self.predict_proba(X)
#     822     if self.n_outputs_ == 1:
#     823         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\.anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:862, in ForestClassifier.predict_proba(self, X)
#     860 check_is_fitted(self)
#     861 # Check data
# --> 862 X = self._validate_X_predict(X)
#     864 # Assign chunk of trees to jobs
#     865 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# ...

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %%
X_train, Y_train, X_test, Y_test = train_test_split(musicx, musicy, test_size = 0.5, random_state = 99 )

# %%
lr = LogisticRegression()
lr.fit(musicx ,musicy)

x = multi_output_clf.predict([[100]])
print(x)
# Out:
# C:\Users\madzi\.anaconda\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 2
#       1 lr = LogisticRegression()
# ----> 2 lr.fit(musicx ,musicy)
#       4 x = multi_output_clf.predict([[100]])
#       5 print(x)
#
# File ~\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:1204, in LogisticRegression.fit(self, X, y, sample_weight)
#    1194     _dtype = [np.float64, np.float32]
#    1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    (...)
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
# -> 1204 check_classification_targets(y)
# ...

# %% [markdown]
# model = XGBRegressor()
# model.fit(X_train, Y_train)
# predictions = model.predict(X_test)
